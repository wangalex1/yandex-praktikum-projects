# %% [markdown]
# ----------
#
# ## <span style="color:green">Комментарий от наставника<span>
#
# Привет! Работа супер, пока читал кафововал! Огонь!
#
# Хочу пройти по пунктам, что получилось, круто:
#
# 1. Загрузка и подготовка данных - прекрасно
# 1. Обработка пропусков - отлично, есть гипотезы по причинам и с учётом решаемой задачи
# 1. Преобразование типов данных - все верно
# 1. Корреляция отлично
# 1. Визуализация тоже хороша и понятна
# 1. Хороший код
# 1. Выводы правильные
# 1. Работа структурирована и хорошо оформлена
#
#
# ### Что нужно доделать, что бы принять работу:
# * Произошло измнения задания. Думаю у тебя не займет много времени переделать работу. Нужно проверить пользовательский рейтинг платформ PS4 и PS3 вместо PS2 и PS3.
# * На этапе работы с пропусками для более правильных выводов рекомендую взглянуть на есть ли связи между пропусками
#
# Удачи
#
# ---------

# %% [markdown]
# Привет Ренат , сделал как ты просил.

# %% [markdown]
# ## Сборный проект

# %% [markdown]
# Описание проекта

# %% [markdown]
# Вы работаете в компании, которая осуществляет продажу компьютерных игр через интернет-магазин и в сети офлайн магазинов.
# Одно из ключевых преимуществ компаний — это анализ данных при планировании закупок и рекламных компаний. Ваша задача
# проанализировать накопленные данные о продажах в разные года, определить тренды и проверить гипотезы. Ваш основной результат — итоговая рекомендация руководству компании о том,
# на каких играх стоит сосредоточиться в будущем году.

# %% [markdown]
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) —
# это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает
# игровой контент и присваивает ему подходящую возрастную категорию, например,
# «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# Инструкция по выполнению проекта

# %% [markdown]
# #### Шаг 1. Откройте файл с данными и изучите общую информацию

# %% [markdown]
# Путь к файлу:

# %% [markdown]
# /datasets/games_data.csv
#
# /datasets/rating.csv — данные о возрастном рейтинге ESRB

# %% [markdown]
# #### Шаг 2. Подготовьте данные

# %% [markdown]
# Посчитайте общее количество продаж и запишите в отдельный столбец.
#
# Приведите данные к нужным типам:
#
# Опишите, в каких столбцах пришлось заменить тип данных и почему
#
# Обработайте пропуски при необходимости:
#
# Если вы решили заполнить пропуски определённым образом или не заполнять совсем — объясните, почему;
#
# Опишите возможные причины возникновения пропусков;
#
# Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Отдельно разберите это значение и опишите, как его обработать.

# %% [markdown]
# #### Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# Постройте распределение количества игр по годам продажи и опишите полученный результат
#
# Постройте распределение по годам продажи для игр с отзывом и без отзыва; cравните полученные распределения и сделайте вывод
#
# Постройте график по суммам продаж каждого года; сделайте вывод
#
# Постройте ящик с усами по общим продажам, опишите полученный результат
#
# Узнайте, на какой платформе было продано больше всего игр
#
# Определите, игр какого жанра больше всего
#
# Найдите игры с наибольшей и наименьшей оценкой от пользователей
#
# Найдите игры с наибольшей и наименьшей оценкой от критиков
#
# Оцените корреляцию между оценками критиков и пользовательскими оценками.

# %% [markdown]
# #### Шаг 4. Составьте портрет пользователя для онлайн и офлайн продаж

# %% [markdown]
# Для покупателей интернет-магазина и сети розничных магазинов определите:
#
# топ-5 предпочтительных жанров
#
# в какие года пользователи были наиболее активны (больше всего покупали игры)
#
# топ-5 предпочтительных платформ
#
# какой рейтинг ESRB встречается чаще всего (наиболее частотная категория)

# %% [markdown]
# #### Шаг 5. Проверьте гипотезы:

# %% [markdown]
# средний пользовательский рейтинг платформ PS4 и PS3 одинаковый;
#
# средний пользовательский рейтинг жанров Action и Sports различается.
#
# Пороговое значение alpha задайте самостоятельно.
#
# Поясните:
#
# как вы формулировали нулевую и альтернативную гипотезы;
#
# какой критерий использовали для проверки гипотез и почему.

# %% [markdown]
# #### Шаг 6. Напишите общий вывод

# %% [markdown]
# Оформление: Задание выполните в Jupyter Notebook. Программный код заполните в ячейках типа code,
#     текстовые пояснения — в ячейках типа markdown.
#     Примените форматирование и заголовки.

# %% [markdown]
# Описание данных
#
# platform — платформа
#
# sales_year — год продажи
#
# genre — жанр игры
#
# online — количество продаж (в сотнях тысяч)
#
# offline — количество продаж (в сотнях тысяч)
#
# critic_score — оценка критиков (максимум 100)
#
# user_score — оценка пользователей (максимум 10)
#
# rating — возрастной рейтинг ESRB
#
# game_id — id игры

# %% [markdown]
# #### Этап 1. Откроем файлы, импортируем библиотеки

# %% [markdown]
# Изучим общую информацию
#
# Посмотрим на оформление

# %%
from IPython.display import Image
from IPython.core.display import HTML
from IPython.core.display import Image, display
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datetime import datetime
from scipy import stats as st
import seaborn as sns

# %%
font = {'family': 'sans-serif',
        'color':  '#a72693',
        'weight': 'normal',
        'size': 20,
        }

# %%
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

# %%
games = pd.read_csv('/datasets/games_data.csv')
games.head()
# Out:
#   platform  sales_year         genre  online  offline  critic_score  \
# 0      PS3    2,017.00        Action  702.00   909.00         97.00
# 1     X360    2,017.00        Action  966.00   514.00         97.00
# 2     X360    2,017.00       Shooter  904.00   424.00         88.00
# 3      PS4    2,015.00       Shooter  603.00   586.00           nan
# 4      3DS    2,017.00  Role-Playing  528.00   419.00           nan
#
#   user_score rating  game_id
# 0        8.2      M    20838
# 1        8.1      M    48673
# 2        3.4      M    17801
# 3        NaN    NaN    12200
# 4        NaN    NaN    11432

# %%
games.describe()
# Out:
#        sales_year   online  offline  critic_score   game_id
# count    4,026.00 4,026.00 4,026.00      1,812.00  4,026.00
# mean     2,016.88    20.62    16.64         71.27 30,186.20
# std          1.01    57.02    48.27         13.10 11,533.93
# min      2,015.00     0.00     0.00         13.00 10,011.00
# 25%      2,016.00     0.00     0.00         64.00 20,125.50
# 50%      2,017.00     4.00     3.00         74.00 30,302.50
# 75%      2,018.00    17.00    13.00         81.00 40,211.25
# max      2,018.00   966.00   909.00         97.00 49,998.00

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4026 entries, 0 to 4025
# Data columns (total 9 columns):
# platform        4026 non-null object
# sales_year      4026 non-null float64
# genre           4026 non-null object
# online          4026 non-null float64
# offline         4026 non-null float64
# critic_score    1812 non-null float64
# user_score      2382 non-null object
# rating          2315 non-null object
# game_id         4026 non-null int64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 283.2+ KB

# %%
rating = pd.read_csv('/datasets/rating.csv')
rating.tail()
# Out:
#   rating_type                   decryption
# 3        E10+       Для всех старше 10 лет
# 4         K-A       Для всех(до 1998 года)
# 5          AO          Только для взрослых
# 6          EC  Для детей младшего возраста
# 7          RP            Рейтинг ожидается

# %%
rating.describe()
# Out:
#        rating_type decryption
# count            8          8
# unique           8          8
# top              E   Для всех
# freq             1          1

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
# rating_type    8 non-null object
# decryption     8 non-null object
# dtypes: object(2)
# memory usage: 208.0+ bytes

# %% [markdown]
# Пойдет. Нужна предобработка.

# %% [markdown]
# #### Шаг 2. Подготовьте данные

# %% [markdown]
# Посчитайте общее количество продаж и запишите в отдельный столбец.
#
# Приведите данные к нужным типам:
#
# Опишите, в каких столбцах пришлось заменить тип данных и почему
#
# Обработайте пропуски при необходимости:
#
# Если вы решили заполнить пропуски определённым образом или не заполнять совсем — объясните, почему;
#
# Опишите возможные причины возникновения пропусков;
#
# Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Отдельно разберите это значение и опишите, как его обработать.

# %%
# Заменим названия столбцов
games.columns.tolist()
# Out:
# ['platform',
#  'sales_year',
#  'genre',
#  'online',
#  'offline',
#  'critic_score',
#  'user_score',
#  'rating',
#  'game_id']

# %%
cols = ['platform',
 'sales_year',
 'genre',
 'online_sales',
 'offline_sales',
 'critic_score',
 'user_score',
 'rating_type',
 'game_id']
games.set_axis(cols, axis='columns', inplace=True)

# %%
games.columns.tolist()
# Out:
# ['platform',
#  'sales_year',
#  'genre',
#  'online_sales',
#  'offline_sales',
#  'critic_score',
#  'user_score',
#  'rating_type',
#  'game_id']

# %%
rating.columns = ['rating_type', 'descryption']
rating.head()
# Out:
#   rating_type             descryption
# 0           E                Для всех
# 1           M               От 17 лет
# 2           T    Подросткам 13—19 лет
# 3        E10+  Для всех старше 10 лет
# 4         K-A  Для всех(до 1998 года)

# %%
#  Подчитаем общее количество продаж и запишитем его  в отдельный столбец
games['total_sales'] = games['online_sales'] + games['offline_sales']

# %%
games.head()
# Out:
#   platform  sales_year         genre  online_sales  offline_sales  \
# 0      PS3    2,017.00        Action        702.00         909.00
# 1     X360    2,017.00        Action        966.00         514.00
# 2     X360    2,017.00       Shooter        904.00         424.00
# 3      PS4    2,015.00       Shooter        603.00         586.00
# 4      3DS    2,017.00  Role-Playing        528.00         419.00
#
#    critic_score user_score rating_type  game_id  total_sales
# 0         97.00        8.2           M    20838     1,611.00
# 1         97.00        8.1           M    48673     1,480.00
# 2         88.00        3.4           M    17801     1,328.00
# 3           nan        NaN         NaN    12200     1,189.00
# 4           nan        NaN         NaN    11432       947.00

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4026 entries, 0 to 4025
# Data columns (total 10 columns):
# platform         4026 non-null object
# sales_year       4026 non-null float64
# genre            4026 non-null object
# online_sales     4026 non-null float64
# offline_sales    4026 non-null float64
# critic_score     1812 non-null float64
# user_score       2382 non-null object
# rating_type      2315 non-null object
# game_id          4026 non-null int64
# total_sales      4026 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 314.6+ KB

# %% [markdown]
# #### Вот, что нужно привести:
#
# год к годам
#
# оценку пользователей к числам с плавающей запятой

# %% [markdown]
# Так есть данные в которых не заполнены даты продажи , но они незначительны и выходы игры в продажу нам не известен и может отличаться 3-5 лет  .Можно их заполнить к примеру  2077  как отсыл к кибепапку 2077

# %% [markdown]
# ![cyberpunk_2077_male_cosplay.jpg](attachment:cyberpunk_2077_male_cosplay.jpg)

# %%
games['sales_year'] = games['sales_year'].fillna(2077)
games['sales_year'] = games['sales_year'].astype('int')

# %%
games['sales_year'] = games['sales_year'].astype('str')

# %%
games['sample_date'] = '-01-01'

# %%
games['sales_year'] = games['sales_year'] + games['sample_date']

# %%
games.head()
# Out:
#   platform  sales_year         genre  online_sales  offline_sales  \
# 0      PS3  2017-01-01        Action        702.00         909.00
# 1     X360  2017-01-01        Action        966.00         514.00
# 2     X360  2017-01-01       Shooter        904.00         424.00
# 3      PS4  2015-01-01       Shooter        603.00         586.00
# 4      3DS  2017-01-01  Role-Playing        528.00         419.00
#
#    critic_score user_score rating_type  game_id  total_sales sample_date
# 0         97.00        8.2           M    20838     1,611.00      -01-01
# 1         97.00        8.1           M    48673     1,480.00      -01-01
# 2         88.00        3.4           M    17801     1,328.00      -01-01
# 3           nan        NaN         NaN    12200     1,189.00      -01-01
# 4           nan        NaN         NaN    11432       947.00      -01-01

# %%
games['sales_year'] = pd.to_datetime(games['sales_year'], format='%Y-%m-%d').dt.year
games.head()
# Out:
#   platform  sales_year         genre  online_sales  offline_sales  \
# 0      PS3        2017        Action        702.00         909.00
# 1     X360        2017        Action        966.00         514.00
# 2     X360        2017       Shooter        904.00         424.00
# 3      PS4        2015       Shooter        603.00         586.00
# 4      3DS        2017  Role-Playing        528.00         419.00
#
#    critic_score user_score rating_type  game_id  total_sales sample_date
# 0         97.00        8.2           M    20838     1,611.00      -01-01
# 1         97.00        8.1           M    48673     1,480.00      -01-01
# 2         88.00        3.4           M    17801     1,328.00      -01-01
# 3           nan        NaN         NaN    12200     1,189.00      -01-01
# 4           nan        NaN         NaN    11432       947.00      -01-01

# %%
del games['sample_date']

# %%
games['sales_year'].max()
# Out:
# 2018

# %%
games['rating_type'].unique()
# Out:
# array(['M', nan, 'E', 'E10+', 'T', 'EC', 'RP'], dtype=object)

# %%
games['user_score'].unique()
# Out:
# array(['8.2', '8.1', '3.4', nan, '5.3', '4.8', '3.2', '8.3', '8.4', '2.6',
#        '7.8', '7.2', '7', '8.7', '4.3', '6.6', '5.7', '5', '7.4', '7.5',
#        '6.5', '9.1', '7.3', '6.9', '6.4', '6.1', '8.6', '7.9', '6.7',
#        '5.4', '4', '8.5', '9', '4.9', '4.5', '6.2', '4.2', '6.3', '7.7',
#        '9.2', '7.6', '8', '3.7', '4.1', '5.8', '5.6', '6.8', '5.5', '4.4',
#        '5.9', '8.9', '3.9', 'tbd', '3.1', '2.9', '6', '4.7', '7.1', '8.8',
#        '5.1', '3.5', '2.5', '3', '2.7', '2.2', '5.2', '1.8', '3.8', '3.3',
#        '4.6', '9.3', '1.6', '3.6', '2.4', '2.8', '1.7', '2.1', '2', '1.5',
#        '0.7', '0.2', '1.2', '0.9', '1.9', '1.3', '1', '1.4', '2.3'],
#       dtype=object)

# %%
# tbd мешает приведению к точке с плавающей запятой, посмотрим подробнее
games[games['user_score'] == 'tbd']['user_score'].count()
# Out:
# 350

# %%
# Так как это что-то неочевидное, то проставим np.nan
games.loc[games['user_score'] == 'tbd','user_score'] = np.nan

# %%
games['user_score'] = games['user_score'].astype('float')
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4026 entries, 0 to 4025
# Data columns (total 10 columns):
# platform         4026 non-null object
# sales_year       4026 non-null int64
# genre            4026 non-null object
# online_sales     4026 non-null float64
# offline_sales    4026 non-null float64
# critic_score     1812 non-null float64
# user_score       2032 non-null float64
# rating_type      2315 non-null object
# game_id          4026 non-null int64
# total_sales      4026 non-null float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 314.6+ KB

# %%
# До полного счастья  проставим строчные буквы в именных столбцах
games['game_id'] = games['game_id'].astype(np.float)
games['platform'] = games['platform'].str.lower()
games['genre'] = games['genre'].str.lower()
games['rating_type'] = games['rating_type'].str.lower()

# %%
rating['rating_type'] = rating['rating_type'].str.lower()
rating['descryption'] = rating['descryption'].str.lower()

# %%
# Обработем пропуски  
games.duplicated().sum()
# Out:
# 0

# %%
games.isnull().sum().sort_values(ascending = False) / games.shape[0] * 100
# Out:
# critic_score    54.99
# user_score      49.53
# rating_type     42.50
# total_sales      0.00
# game_id          0.00
# offline_sales    0.00
# online_sales     0.00
# genre            0.00
# sales_year       0.00
# platform         0.00
# dtype: float64

# %% [markdown]
# Заполним оценки нулями, так как не известны причины отсутствия рейтинга. Даже если предположить, что на одной платформе игра вышла крутой, то совершенно необязательно она выйдет крутой на другой платформе.
#
# У безымянных тоже есть  деньги,  оставим их
#
# Игры на разных платформах могут отличаться рейтингом.
# Даже могут отличаться контентом, поэтому поставим всем общую группу "Вне рейтинга".

# %% [markdown]
# Там где существует рейтинг 0 , можно заменить значение 0 на -1

# %%
games['user_score'] = games['user_score'].fillna(-1)
games['critic_score'] = games['critic_score'].fillna(-1)
games['rating_type'] = games['rating_type'].fillna('out of rating')
games['genre'] = games['genre'].fillna('no genre game')
games['game_id'] = games['game_id'].fillna('no game_id ')

# %%
games.head()
# Out:
#   platform  sales_year         genre  online_sales  offline_sales  \
# 0      ps3        2017        action        702.00         909.00
# 1     x360        2017        action        966.00         514.00
# 2     x360        2017       shooter        904.00         424.00
# 3      ps4        2015       shooter        603.00         586.00
# 4      3ds        2017  role-playing        528.00         419.00
#
#    critic_score  user_score    rating_type   game_id  total_sales
# 0         97.00        8.20              m 20,838.00     1,611.00
# 1         97.00        8.10              m 48,673.00     1,480.00
# 2         88.00        3.40              m 17,801.00     1,328.00
# 3         -1.00       -1.00  out of rating 12,200.00     1,189.00
# 4         -1.00       -1.00  out of rating 11,432.00       947.00

# %% [markdown]
# #### 3. Проведите исследовательский анализ данных
#
# Постройте распределение по годам релиза и опишите полученный результат
#
# Постройте распределение по годам релиза для игр с отзывом и без отзыва; cравните полученные распределения и сделайте вывод
#
# Постройте график продаж по каждому году; сделайте вывод
#
# Постройте ящик с усами по глобальным продажам, опишите полученный результат
#
# Узнайте, на какой платформе было выпущено больше всего игр
#
# Определите, игр какого жанра больше всего
#
# Найдите игры с наибольшей и наименьшей оценкой от пользователей
#
# Найдите игры с наибольшей и наименьшей оценкой от критиков
#
# Оцените корреляцию между оценками критиков и пользовательскими оценками

# %% [markdown]
# #### 1. Постройте распределение по годам релиза и опишите полученный результат

# %%
ax = games[games['sales_year'] != 2077]['sales_year'].plot(kind='hist', bins=40).legend()
plt.title('Распределение по годам продажи', fontdict=font)
# Out:
# Text(0.5, 1.0, 'Распределение по годам продажи')

# %% [markdown]
# По графику понятно , что рынок можно сказать рос до 2018 года , потом кризис в каком то смысле
# насыщение рынка, переход на мобильные платформы, ну и, видимо, инвесторы стали меньше рисковать перестали.

# %% [markdown]
# #### 2. Постройте распределение по годам релиза для игр с отзывом и без отзыва; cравните полученные распределения и сделайте вывод

# %%
games[(games['sales_year'] != 2077) & (games['critic_score'] > 0)]['sales_year'].plot(kind='hist', bins=25).legend()
games[(games['sales_year'] != 2077) & (games['critic_score'] == -1)]['sales_year'].plot(kind='hist', bins=25, alpha=0.5).legend()
plt.title('Отзывы и без отзыва — критики', fontdict=font)
# Out:
# Text(0.5, 1.0, 'Отзывы и без отзыва — критики')

# %%
games[(games['sales_year'] != 2077) & (games['user_score'] > 0)]['sales_year'].plot(kind='hist', bins=25).legend()
games[(games['sales_year'] != 2077) & (games['user_score'] == -1)]['sales_year'].plot(kind='hist', bins=25, alpha=0.5).legend()
plt.title('Отзывы и без отзыва — пользователи', fontdict=font)
# Out:
# Text(0.5, 1.0, 'Отзывы и без отзыва — пользователи')

# %% [markdown]
# Выглядят похожими между собой. Скорее всего, из-за того, что чаще всего критикам видимо выгодно сходится с мнением пользователей.

# %% [markdown]
# #### 3. Постройте график продаж по каждому году; сделайте вывод

# %%
games[games['sales_year'] != 2077].groupby('sales_year').agg({'total_sales':'sum'}).plot()
games[games['sales_year'] != 2077].groupby('sales_year').agg({'online_sales':'sum'}).plot()
games[games['sales_year'] != 2077].groupby('sales_year').agg({'offline_sales':'sum'}).plot()

# %% [markdown]
# Ну все тоже самое рос рынок пока не ударил кризис , и опять же в 2 раза поднялся курс доллара это тоже сказалось на продажах

# %% [markdown]
# #### 4. Постройте ящик с усами по общим продажам, опишите полученный результат

# %%
games.describe()
# Out:
#        sales_year  online_sales  offline_sales  critic_score  user_score  \
# count    4,026.00      4,026.00       4,026.00      4,026.00    4,026.00
# mean     2,016.88         20.62          16.64         31.53        2.85
# std          1.01         57.02          48.27         37.02        3.97
# min      2,015.00          0.00           0.00         -1.00       -1.00
# 25%      2,016.00          0.00           0.00         -1.00       -1.00
# 50%      2,017.00          4.00           3.00         -1.00        2.00
# 75%      2,018.00         17.00          13.00         72.00        7.00
# max      2,018.00        966.00         909.00         97.00        9.30
#
#         game_id  total_sales
# count  4,026.00     4,026.00
# mean  30,186.20        37.25
# std   11,533.93        99.36
# min   10,011.00         0.00
# 25%   20,125.50         0.00
# 50%   30,302.50         8.00
# 75%   40,211.25        31.00
# max   49,998.00     1,611.00

# %% [markdown]
# Вот что у нас с графиком.

# %%
games["total_sales"].plot(kind = "box",
                      vert = False)

# %% [markdown]
# Можно по красивее.

# %%
stats = games["total_sales"].describe()

print(stats.map("{:.2f}".format))

Q25 = stats[4]
Q75 = stats[6]
IQR = Q75 - Q25
lower = max(round(Q25 - IQR * 1.5, 2), 0)
higher = round(Q75 + IQR * 1.5, 2)

plt.figure(figsize = (15,1))

g = sns.boxplot(x = games[games["total_sales"] <= higher]["total_sales"],
                fliersize=1,
                saturation = 0.5,
                color = (1, 0, 0),
                width = 0.4)
# Out:
# count    4026.00
# mean       37.25
# std        99.36
# min         0.00
# 25%         0.00
# 50%         8.00
# 75%        31.00
# max      1611.00
# Name: total_sales, dtype: object

# %% [markdown]
# Все очень не однозначно  - выпустить какую-нибудь игру и заработать на этом немного денег , тем более что много  на рынке много инди - разработчиков , не факт, что не в минус. Но игровые конгломераты не дремлют и устраивают AAA-выбросы рынку.

# %% [markdown]
# #### 5. Узнайте, на какой платформе было выпущено больше всего игр

# %%
most_popular_platform = games.groupby('platform').agg({'game_id':'count'}).reset_index()
most_popular_platform.sort_values(by='game_id', ascending=False).head()
# Out:
#    platform  game_id
# 4       ps3      708
# 0       3ds      512
# 10     x360      498
# 7       psv      431
# 5       ps4      393

# %% [markdown]
# Неудивительно , что Плейстейшн 3 побеждает.

# %% [markdown]
# #### 6. Определите, игр какого жанра больше всего

# %%
most_popular_genre = games.groupby('genre').agg({'game_id':'count'}).reset_index()
most_popular_genre.sort_values(by='game_id', ascending=False).head()
# Out:
#            genre  game_id
# 0         action     1270
# 7   role-playing      467
# 1      adventure      410
# 10        sports      389
# 3           misc      375

# %% [markdown]
# Экшен победил.

# %% [markdown]
# #### 7. Найдите игры с наибольшей и наименьшей оценкой:
#
# от пользователей
#
# от критиков

# %% [markdown]
# #### Оцените корреляцию между оценками критиков и пользовательскими оценками

# %%
games[games['user_score'] > 0].sort_values(by='user_score').head()
# Out:
#      platform  sales_year     genre  online_sales  offline_sales  \
# 2118      ps3        2016    sports          7.00           2.00
# 1739     x360        2016    sports         14.00           2.00
# 2695       ds        2017  platform          6.00           0.00
# 3026      ps3        2017    racing          2.00           1.00
# 2321     x360        2017   shooter          7.00           2.00
#
#       critic_score  user_score rating_type   game_id  total_sales
# 2118         -1.00        0.20           e 23,493.00         9.00
# 1739         -1.00        0.70           e 28,773.00        16.00
# 2695         -1.00        0.90           e 14,384.00         6.00
# 3026         13.00        1.00           m 28,618.00         3.00
# 2321         43.00        1.20           m 24,620.00         9.00

# %%
games[games['user_score'] > 0].sort_values(by='user_score', ascending = False).head()
# Out:
#      platform  sales_year         genre  online_sales  offline_sales  \
# 2348      psv        2015     adventure          0.00           3.00
# 639        pc        2015  role-playing         21.00          46.00
# 77        ps4        2015  role-playing        102.00         213.00
# 339      xone        2015  role-playing         69.00          50.00
# 2277      psv        2017     adventure          4.00           4.00
#
#       critic_score  user_score rating_type   game_id  total_sales
# 2348         86.00        9.30           m 38,270.00         3.00
# 639          93.00        9.30           m 12,365.00        67.00
# 77           92.00        9.20           m 43,575.00       315.00
# 339          91.00        9.20           m 10,495.00       119.00
# 2277         83.00        9.20           m 27,691.00         8.00

# %%
games[games['critic_score'] > 0].sort_values(by='critic_score').head()
# Out:
#      platform  sales_year   genre  online_sales  offline_sales  critic_score  \
# 3026      ps3        2017  racing          2.00           1.00         13.00
# 2812     x360        2017  racing          4.00           1.00         19.00
# 2127      ps4        2015  sports          4.00           6.00         19.00
# 2415     xone        2015  sports          3.00           5.00         20.00
# 2121     x360        2017  sports          8.00           3.00         21.00
#
#       user_score rating_type   game_id  total_sales
# 3026        1.00           m 28,618.00         3.00
# 2812        1.30           m 11,902.00         5.00
# 2127        3.40           e 12,797.00        10.00
# 2415        3.10           e 42,977.00         8.00
# 2121        5.00           t 18,203.00        11.00

# %%
games[games['critic_score'] > 0].sort_values(by='critic_score', ascending = False).head()
# Out:
#    platform  sales_year         genre  online_sales  offline_sales  \
# 0       ps3        2017        action        702.00         909.00
# 9       ps4        2018        action        396.00         631.00
# 44     xone        2018        action        281.00         219.00
# 1      x360        2017        action        966.00         514.00
# 19     x360        2017  role-playing        505.00         279.00
#
#     critic_score  user_score rating_type   game_id  total_sales
# 0          97.00        8.20           m 20,838.00     1,611.00
# 9          97.00        8.30           m 28,618.00     1,027.00
# 44         97.00        7.90           m 39,055.00       500.00
# 1          97.00        8.10           m 48,673.00     1,480.00
# 19         96.00        8.40           m 29,673.00       784.00

# %%
critic_score = games[games['critic_score'] != -1]
user_score = games[games['user_score'] != -1]

# %%
corr_df = pd.DataFrame()
corr_df['critic_score'] = critic_score['critic_score']
corr_df['user_score'] = user_score['user_score']

# %%
corr = corr_df[['critic_score', 'user_score']].corr()
corr.style.format("{:.2%}")
# Out:
# <style  type="text/css" >
# </style><table id="T_f4b929d8_da66_11e9_bdd5_02420a00021e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >critic_score</th>        <th class="col_heading level0 col1" >user_score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f4b929d8_da66_11e9_bdd5_02420a00021elevel0_row0" class="row_heading level0 row0" >critic_score</th>
#                         <td id="T_f4b929d8_da66_11e9_bdd5_02420a00021erow0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_f4b929d8_da66_11e9_bdd5_02420a00021erow0_col1" class="data row0 col1" >53.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_f4b929d8_da66_11e9_bdd5_02420a00021elevel0_row1" class="row_heading level0 row1" >user_score</th>
#                         <td id="T_f4b929d8_da66_11e9_bdd5_02420a00021erow1_col0" class="data row1 col0" >53.49%</td>
# ...

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f4e92f48_da66_11e9_bdd5_02420a00021erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4e92f48_da66_11e9_bdd5_02420a00021erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f4e92f48_da66_11e9_bdd5_02420a00021erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f4e92f48_da66_11e9_bdd5_02420a00021erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_f4e92f48_da66_11e9_bdd5_02420a00021e" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >critic_score</th>        <th class="col_heading level0 col1" >user_score</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# В общем, по-прежнему, сильная корреляция есть

# %% [markdown]
# #### 4. Составьте портрет  пользователя для онлайн и офлайн продаж

# %% [markdown]
# Для интернет-магазина и сети розничных магазинов определите:
#
# топ-5 предпочтительных жанров
#
# в какие года пользователи были наиболее активны (больше всего покупали игры)
#
# топ-5 предпочтительных платформ
#
# какой рейтинг ESRB встречается чаще всего (наиболее частотная категория)

# %% [markdown]
# #### Топ-5 предпочтительных жанров

# %%
games.groupby(by='genre').agg({'online_sales':'sum'}).sort_values(by='online_sales', ascending=False).head(5).plot(kind='bar')
games.groupby(by='genre').agg({'offline_sales':'sum'}).sort_values(by='offline_sales', ascending=False).head(5).plot(kind='bar')

# %% [markdown]
# Картина практический одинаковая у всех мода  на экшены

# %% [markdown]
# #### В какие года пользователи были наиболее активны (больше всего покупали игры)

# %%
games.groupby(by='sales_year').agg({'online_sales':'sum'}).sort_values(by='online_sales', ascending=False).head().plot(kind='bar')
games.groupby(by='sales_year').agg({'offline_sales':'sum'}).sort_values(by='offline_sales', ascending=False).head().plot(kind='bar')
games.groupby(by='sales_year').agg({'total_sales':'sum'}).sort_values(by='total_sales', ascending=False).head().plot(kind='bar')

# %% [markdown]
# В общем,  рынок игровой рос, а в 2018 упал , дальше данных нет.

# %% [markdown]
# #### Какой рейтинг ESRB встречается чаще всего (наиболее частотная категория)

# %%
games.head()
# Out:
#   platform  sales_year         genre  online_sales  offline_sales  \
# 0      ps3        2017        action        702.00         909.00
# 1     x360        2017        action        966.00         514.00
# 2     x360        2017       shooter        904.00         424.00
# 3      ps4        2015       shooter        603.00         586.00
# 4      3ds        2017  role-playing        528.00         419.00
#
#    critic_score  user_score    rating_type   game_id  total_sales
# 0         97.00        8.20              m 20,838.00     1,611.00
# 1         97.00        8.10              m 48,673.00     1,480.00
# 2         88.00        3.40              m 17,801.00     1,328.00
# 3         -1.00       -1.00  out of rating 12,200.00     1,189.00
# 4         -1.00       -1.00  out of rating 11,432.00       947.00

# %%
games = games.merge(rating, on='rating_type', how='right')

# %%
games.head()
# Out:
#   platform  sales_year    genre  online_sales  offline_sales  critic_score  \
# 0      ps3    2,017.00   action        702.00         909.00         97.00
# 1     x360    2,017.00   action        966.00         514.00         97.00
# 2     x360    2,017.00  shooter        904.00         424.00         88.00
# 3      ps3    2,018.00  shooter        499.00         573.00         83.00
# 4     x360    2,018.00  shooter        825.00         424.00         83.00
#
#    user_score rating_type   game_id  total_sales descryption
# 0        8.20           m 20,838.00     1,611.00   от 17 лет
# 1        8.10           m 48,673.00     1,480.00   от 17 лет
# 2        3.40           m 17,801.00     1,328.00   от 17 лет
# 3        5.30           m 28,109.00     1,072.00   от 17 лет
# 4        4.80           m 43,830.00     1,249.00   от 17 лет

# %%
games.groupby(by='descryption').agg({'online_sales':'sum'}).sort_values(by='online_sales', ascending=False).head(5).plot(kind='bar')
games.groupby(by='descryption').agg({'offline_sales':'sum'}).sort_values(by='offline_sales', ascending=False).head(5).plot(kind='bar')
games.groupby(by='descryption').agg({'total_sales':'sum'}).sort_values(by='total_sales', ascending=False).head(5).plot(kind='bar')

# %% [markdown]
#  По всем рейтингам картина примерно одинаковая . Основные пользователи от 17 лет и для всех.

# %% [markdown]
# #### Топ-5 предпочтительных платформ

# %%
games.groupby(by='platform').agg({'online_sales':'sum'}).sort_values(by='online_sales', ascending=False).head(5).plot(kind='bar')
games.groupby(by='platform').agg({'offline_sales':'sum'}).sort_values(by='offline_sales', ascending=False).head(5).plot(kind='bar')
games.groupby(by='platform').agg({'total_sales':'sum'}).sort_values(by='total_sales', ascending=False).head(5).plot(kind='bar')

# %% [markdown]
# По online x360 по offline ps3 и общие продажи x360

# %% [markdown]
# #### 5. Проверьте гипотезы

# %% [markdown]
# средний пользовательский рейтинг платформ PS3 и PS4 одинаковый
#
# средний пользовательский рейтинг жанров Action и Sports различается
#
# Пороговое значение alpha задайте самостоятельно.
#
# Поясните:
#
# как вы формулировали нулевую и альтернативную гипотезы
#
# какой критерий использовали для проверки гипотез и почему

# %% [markdown]
# Будем использовать t-критерий Стьюдента, так как сравниваемые выборки независимы между собой.

# %% [markdown]
# Гипотезы:

# %% [markdown]
# H0: средний пользовательский рейтинг платформ PS3 и PS4 одинаковый
#
# H1: средний пользовательский рейтинг платформ PS3 и PS4 различается

# %%
alpha = 0.05

# %%
ps3 = games[(games['platform'] == 'ps3') & (games['user_score'] > 0)]['user_score']
ps4 = games[(games['platform'] == 'ps4') & (games['user_score'] > 0)]['user_score']

# %%
results = st.ttest_ind(ps3, ps4)

# %%
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.2637151315702736
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Гипотезы:

# %% [markdown]
# H0: средний пользовательский рейтинг жанров Action и Sports одинаковый
#
# H1: средний пользовательский рейтинг жанров Action и Sports различается

# %%
action = games[(games['genre'] == 'action') & (games['user_score'] > 0)]['user_score']
sports = games[(games['genre'] == 'sports') & (games['user_score'] > 0)]['user_score']

# %%
results = st.ttest_ind(action, sports)

# %%
print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 8.781381917753635e-23
# Отвергаем нулевую гипотезу

# %% [markdown]
# #### 6. Напишите общий вывод

# %% [markdown]
# Данных слишком мало . Видно, что в кризис продажи упали .
# Ну и россиянам ролевые игры нравятся.

# %% [markdown]
# #### Рекомендации

# %% [markdown]
# Может сделать мешьше лутбоксов ? Хотя врядли на это разработчики  пойдут
#
# Склеить наборы данных с играми и рейтингами
#
# Указывать источники отзывов, заполнять набор данных без пропусков
#
# Перед тем, как начать делать игру искать спонсора или инвестора
